# %% [markdown]
# <a href="https://colab.research.google.com/github/SajaKhatb/Task1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %% [markdown]
# Import the needed libraries

# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
from numpy import pi
from skimage import io
from numpy import r_
from google.colab.patches import cv2_imshow
from scipy.fftpack import dct, idct
import cv2 as cv
import numpy as image_3d
import matplotlib.pylab as plt
import matplotlib.pylab as pylab

# %% [markdown]
# Define 2D-DCT and IDCT

# %%
def dct2(a):
    return dct(dct(a.T, norm='ortho').T, norm='ortho')

def idct2(a):
    return idct(idct(a.T, norm='ortho').T, norm='ortho')

# %% [markdown]
# Display image and converted it to matrix

# %%
url = "https://photo-works.net/images/tutorial/how-ot-make-picture-black-and-white-after.jpg"
image = io.imread(url)
#show the image
cv2_imshow(image)
#show the matrix
print (image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x395 at 0x7F9F07FF4110>
# [[[ 24  24  24]
#   [ 26  26  26]
#   [ 29  29  29]
#   ...
#   [ 26  26  26]
#   [ 29  29  29]
#   [ 30  30  30]]
#
#  [[ 27  27  27]
#   [ 29  29  29]
#   [ 32  32  32]
#   ...
#   [ 26  26  26]
#   [ 28  28  28]
#   [ 29  29  29]]
#
#  [[ 31  31  31]
#   [ 33  33  33]
#   [ 36  36  36]
#   ...
#   [ 29  29  29]
#   [ 31  31  31]
#   [ 32  32  32]]
#
#  ...
#
#  [[ 91  91  91]
#   [ 89  89  89]
#   [ 87  87  87]
#   ...
#   [ 78  78  78]
#   [ 68  68  68]
#   [ 97  97  97]]
#
#  [[ 93  93  93]
#   [ 91  91  91]
#   [ 89  89  89]
#   ...
#   [110 110 110]
#   [ 94  94  94]
#   [ 95  95  95]]
#
#  [[ 93  93  93]
#   [ 91  91  91]
#   [ 89  89  89]
#   ...
#   [143 143 143]
#   [128 128 128]
#   [128 128 128]]]

# %% [markdown]
# Performing 2D-DCT on image block

# %%
imsize = im.shape
dct = np.zeros(imsize)
#applay DCT on 8X8 
for i in r_[:imsize[0]:8]:  
  for j in r_[:imsize[1]:8]:
    dct[i:(i+8),j:(j+8)] = scipy.fftpack.dct( scipy.fftpack.dct( im[i:(i+8),j:(j+8)], axis=0, norm='ortho' ), axis=1, norm='ortho' )

# %% [markdown]
# Apllyaing DCT on all image blocks

# %%
#show DCT 
plt.figure()
plt.imshow(dct,vmax = np.max(dct)*0.01,vmin = 0)
print(dct)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[ 3.30875000e+02  3.30875000e+02  3.30875000e+02]
#   [-3.04631776e+01 -3.04631776e+01 -3.04631776e+01]
#   [ 2.80213456e-02  2.80213456e-02  2.80213456e-02]
#   ...
#   [ 1.39495180e-01  1.39495180e-01  1.39495180e-01]
#   [ 5.80341069e-02  5.80341069e-02  5.80341069e-02]
#   [ 4.71115228e-01  4.71115228e-01  4.71115228e-01]]
#
#  [[-4.99683315e+01 -4.99683315e+01 -4.99683315e+01]
#   [-5.06433419e+00 -5.06433419e+00 -5.06433419e+00]
#   [-5.03103863e-02 -5.03103863e-02 -5.03103863e-02]
#   ...
#   [-3.65484942e-01 -3.65484942e-01 -3.65484942e-01]
#   [ 9.09910748e-02  9.09910748e-02  9.09910748e-02]
#   [-9.47461064e-02 -9.47461064e-02 -9.47461064e-02]]
#
#  [[-1.63320371e-01 -1.63320371e-01 -1.63320371e-01]
#   [-1.73740801e-01 -1.73740801e-01 -1.73740801e-01]
#   [ 3.66116524e-02  3.66116524e-02  3.66116524e-02]
#   ...
#   [-2.18439970e-01 -2.18439970e-01 -2.18439970e-01]
#   [ 3.90165043e-01  3.90165043e-01  3.90165043e-01]
#   [-2.90709090e-01 -2.90709090e-01 -2.90709090e-01]]
#
#  ...
#
#  [[ 4.27435960e+02  4.27435960e+02  4.27435960e+02]
#   [ 1.42997213e+01  1.42997213e+01  1.42997213e+01]
#   [-3.77172240e-01 -3.77172240e-01 -3.77172240e-01]
#   ...
#   [-1.56921709e+01 -1.56921709e+01 -1.56921709e+01]
#   [ 8.03568720e+00  8.03568720e+00  8.03568720e+00]
#   [ 3.68470579e-01  3.68470579e-01  3.68470579e-01]]
#
#  [[-4.50000000e+00 -4.50000000e+00 -4.50000000e+00]
#   [ 6.40728862e-01  6.40728862e-01  6.40728862e-01]
#   [-4.61939766e-01 -4.61939766e-01 -4.61939766e-01]
#   ...
#   [-1.04523814e+01 -1.04523814e+01 -1.04523814e+01]
#   [ 3.51621370e-02  3.51621370e-02  3.51621370e-02]
#   [-1.50192027e-01 -1.50192027e-01 -1.50192027e-01]]
#
#  [[-2.59807621e+00 -2.59807621e+00 -2.59807621e+00]
#   [ 3.69924981e-01  3.69924981e-01  3.69924981e-01]
#   [-2.66701048e-01 -2.66701048e-01 -2.66701048e-01]
#   ...
#   [-5.96035343e+00 -5.96035343e+00 -5.96035343e+00]
#   [-4.90106340e-02 -4.90106340e-02 -4.90106340e-02]
#   [-2.07696051e-01 -2.07696051e-01 -2.07696051e-01]]]

# %% [markdown]
# Convert the last K coeffcients to zero

# %%
#threshold value 
threshhold = 0.011
dct_thresh = dct * (abs(dct) > (threshhold*np.max(dct)))
#show the image after changing 
plt.figure()
plt.imshow(dct_thresh,vmax = np.max(dct)*0.01,vmin = 0)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# applaying IDCT

# %%
idct1 = idct2(dct1)
cv2_imshow(idct1)
# Out:
# <PIL.Image.Image image mode=RGB size=600x395 at 0x7F9F079DE710>
